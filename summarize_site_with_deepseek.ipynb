# %%
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
import requests
from dotenv import load_dotenv
import os
import ollama

# %%
load_dotenv(override=True)
model_name = os.getenv('MODEL_NAME')

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://stackoverflow.com/")
print(ed.title)
print(ed.text)
# Out:
# Newest Questions - Stack Overflow
# Skip to main content
# Stack Overflow
# About
# Products
# OverflowAI
# Stack Overflow for Teams
# Where developers & technologists share private knowledge with coworkers
# Advertising & Talent
# Reach devs & technologists worldwide about your product, service or employer brand
# OverflowAI
# GenAI features for Teams
# OverflowAPI
# Train & fine-tune LLMs
# Labs
# The future of collective knowledge sharing
# About the company
# Visit the blog
# Loading…
# current community
# Stack Overflow
# help
# chat
# Meta Stack Overflow
# your communities
# Sign up
# or
# log in
# to customize your list.
# more stack exchange communities
# company blog
# Log in
# Sign up
# Home
# Questions
# Tags
# Users
# Companies
# Labs
# Discussions
# Collectives
# Communities for your favorite technologies.
# Explore all Collectives
# Teams
# Ask questions, find answers and collaborate at work with Stack Overflow for Teams.
# Try Teams for free
# Explore Teams
# Teams
# Ask questions, find answers and collaborate at work with Stack Overflow for Teams.
# Explore Teams
# Collectives™ on Stack Overflow
# Find centralized, trusted content and collaborate around the technologies you use most.
# Learn more about Collectives
# Teams
# Q&A for work
# Connect and share knowledge within a single location that is structured and easy to search.
# Learn more about Teams
# Get early access and see previews of new features.
# Learn more about Labs
# Newest Questions
# Ask Question
# 24,248,666 questions
# Newest
# Active
# Bountied
# 68
# Unanswered
# More
# Bountied
# 68
# Unanswered
# Frequent
# Score
# Trending
# Week
# Month
# Unanswered (my tags)
# Filter
# Filter by
# No answers
# No accepted answer
# Has bounty
# Days old
# Sorted by
# Newest
# Recent activity
# Highest score
# Most frequent
# Bounty ending soon
# Trending
# Most activity
# Tagged with
# My watched tags
# The following tags:
# Apply filter
# Cancel
# 0
# votes
# 0
# answers
# 2
# views
# Parallel downloading stalls in S3
# I am trying to download FASTA files from a publicly available S3 bucket to my local machine, needing to download approximately 5 million files. The download script contains a list of wget commands, ...
# amazon-web-services
# amazon-s3
# wget
# gnu-parallel
# Ismail Gumustop
# 13
# asked
# 1 min ago
# 0
# votes
# 0
# answers
# 4
# views
# Select the largest available data type in Numpy
# I'm working on numerical algorithms and I have a Numpy backend for fast, fixed-precision calculations.
# During the initialization of the interface I let the user choose among the complex data types np....
# python
# numpy
# NYG
# 1,817
# asked
# 3 mins ago
# 0
# votes
# 0
# answers
# 4
# views
# Why are the colors mixed up in this screenshot taken using Robot.js?
# I'm using Robot.js to take screenshots (I don't really want to install any other heavy packages over 1 mb, but I'm already using Robot.js and no, Jimp isn't what I'm looking for). Since the ...
# node.js
# png
# zlib
# crc32
# robotjs
# Dinoscape Dinoscape
# 34
# asked
# 4 mins ago
# 0
# votes
# 0
# answers
# 5
# views
# Histogram for integer values
# Having a very simple integer data, is there a very simple way to display a histogram of them, so that each histogram bar corresponds to a single integer value?
# Right now, hist(a) for integer vector a ...
# r
# histogram
# Tomas
# 59.5k
# asked
# 4 mins ago
# -1
# votes
# 0
# answers
# 5
# views
# Fastest way for IPC between a C++ application and a NodeJS server
# I have an application that needs low-level interface between the running system and also to serve a webpage for interaction. Basically, the C++ app collects message from a series of sockets, raw ...
# c++
# node.js
# ipc
# Gianfranco Di Domenico
# 86
# asked
# 4 mins ago
# 0
# votes
# 0
# answers
# 4
# views
# Test cobra cli subcommand flags
# I use cobra and viper for context. I want to test a subcommand with flag. So I have a root command with init function as following
# SubCmd.Flags().Bool("test-flag", false, "It is a flag&...
# go
# go-cobra
# Manoj Kommineni
# 81
# asked
# 4 mins ago
# 0
# votes
# 0
# answers
# 6
# views
# Nodejs Filepath incorrect, fs module
# I am watching an NodeJs course on udemy and i'm trying to learn from there, but there is an error when im trying to write and read files with fs module it is giving me back this error.
# undefined:1
# ...
# node.js
# node.js-fs
# Shpresim Musliu
# 1
# asked
# 5 mins ago
# 0
# votes
# 0
# answers
# 12
# views
# What is the difference between writing in one and two lines when transporting a matrix?
# If the replacement of elements is written in two lines, then the matrix is ​​transported incorrectly
# x=[[i for i in list(map(int,input().split()))]
#    for _ in range(int(input()))]
# print("Result:...
# for-loop
# matrix
# nested-loops
# Kit_kat_rin
# 1
# asked
# 7 mins ago
# 0
# votes
# 0
# answers
# 10
# views
# Canceling a react-query mutation
# I have a mutation that comprises of a sequence of long-running actions:
# useMutation({
#   mutationFn: async () => {
#     await firstTask()
#     await secondTask()
#     await thirdTask()
#   },
#   ...
# })
#
# I ...
# javascript
# reactjs
# react-query
# tanstackreact-query
# Undistraction
# 43.6k
# asked
# 8 mins ago
# 0
# votes
# 0
# answers
# 10
# views
# Ambiguous conversion warning: should I care?
# This question can be considered probably theoretical as I don't see why I would have such design in real code.
# I've got two classes with some conversion operators:
# class B;
# class A {
#    public:
#     A()...
# c++
# type-conversion
# gcc-warning
# Oersted
# 2,516
# asked
# 11 mins ago
# -1
# votes
# 0
# answers
# 11
# views
# What is best practice in working with Freelancers on Django project? [closed]
# I have a website written using Django, Bootstrap5, jQuery. As the project gets increasingly time consuming, I want to let freelance developers contribute. What is best practice in this regard. Is ...
# django
# collaboration
# gitlab-ce
# T_Torture
# 457
# asked
# 11 mins ago
# 0
# votes
# 0
# answers
# 6
# views
# laravel-modules api routes don't hit the controller
# I am using laravel-modules 11.1.8 and with laravel 11.41.3 for an SPA (vue3).
# The problem is the vue components inside the module, when calling the api routes defined in the module, returns the app ...
# laravel
# vuejs3
# laravel-modules
# calin24
# 981
# asked
# 11 mins ago
# 0
# votes
# 0
# answers
# 3
# views
# Running jcmd JFR.dump seems to stall the JVM. How can I fix this?
# Flight recording is enabled with disk=false when the service starts and a timer service triggers jcmd <PID> JFR.dump every five minutes to capture flight recordings to a file.
# However we notice ...
# java
# jvm
# jfr
# jcmd
# swpalmer
# 4,371
# asked
# 12 mins ago
# 0
# votes
# 0
# answers
# 3
# views
# AMI Charges on AWS clout
# I want to know if I install multiple software on a Linux environment in an EC2 instance and create an AMI to save it for future use, will I be charged by AWS, or is it free?"
# amazon-web-services
# amazon-ec2
# vivek kumar
# 1
# asked
# 13 mins ago
# 0
# votes
# 1
# answer
# 16
# views
# TailwindCSS styling is not applied
# I have the following project.
# vite.config.js
# import { fileURLToPath, URL } from 'node:url'
#
# import { defineConfig } from 'vite'
# import vue from '@vitejs/plugin-vue'
# import vueDevTools from 'vite-...
# vue.js
# tailwind-css
# vite
# primevue
# kerner1000
# 3,546
# asked
# 19 mins ago
# 15
# 30
# 50
# per page
# 1
# 2
# 3
# 4
# 5
# …
# 1616578
# Next
# The Overflow Blog
# Will the web ever be the primary delivery system for 3D games?
# Investing in the Stack Exchange Network and the future of Stack Overflow
# Featured on Meta
# AI-generated Answers experiment on Stack Exchange sites that volunteered to...
# Join us for our first community-wide AMA (Ask Me Anything) with Stack...
# The landing page at stackoverflow.com will point directly to Q&A beginning...
# Upcoming Experiment for Commenting
# Policy: Generative AI (e.g., ChatGPT) is banned
# Collectives
# see all
# Google Cloud
# 61k Members
# Join
# A collective for developers who utilize Google Cloud’s infrastructure and platform capabilities. This collective is organized and managed by the Stack Overflow community.
# Microsoft Azure
# 25k Members
# Join
# A collective for developers to engage, share, and learn about Microsoft Azure’s open-source frameworks, languages, and platform. This collective is organized and managed by the Stack Overflow community.
# R Language
# 12k Members
# Join
# A collective where data scientists and AI researchers gather to find, share, and learn about R and other subtags like knitr and dplyr.
# Related Tags
# javascript
# ×
# 2533359
# python
# ×
# 2213085
# java
# ×
# 1920587
# c#
# ×
# 1624676
# php
# ×
# 1468490
# android
# ×
# 1420349
# html
# ×
# 1189321
# jquery
# ×
# 1036850
# c++
# ×
# 813523
# css
# ×
# 808025
# ios
# ×
# 688698
# sql
# ×
# 674856
# mysql
# ×
# 661387
# r
# ×
# 510595
# reactjs
# ×
# 481368
# node.js
# ×
# 473700
# arrays
# ×
# 418320
# c
# ×
# 407418
# asp.net
# ×
# 374430
# json
# ×
# 361322
# python-3.x
# ×
# 343153
# .net
# ×
# 340915
# ruby-on-rails
# ×
# 338383
# sql-server
# ×
# 336659
# swift
# ×
# 336244
# more related tags
# Hot Network Questions
# How to remove 'newline' from 'here string'
# Replacing window function OVER() with WINDOW clause reference yields different results
# Identify the component: stack of metal plates
# lndir shell function - hardlink two directories
# Why is the ellipse a good approximation to a catenary for these cases?
# QGIS - Merge 2 layers and also merge the Categorised Symbology
# Linearizing fractional objective with double summations
# Why is my washer drain pipe in middle of floor?
# What spot in The Hobbit was Del Toro talking about here?
# In principle, could the Many-Worlds Interpretation be tested via interference?
# When did Lotus 1-2-3 for DOS start supporting the 8087 math coprocessor?
# Half Price for Every Second Pizza
# Can someone steal your music by copyrighting it with copyright.gov before you do?
# Slowly losing hard drive space
# How might a police state be a 'good thing'
# Knight and Knave, But With a Twist
# Does ice exist at 2 atm, 0 °C?
# How can I lubricate a security hinge?
# Why would a near future, interstellar empire still have military units/divisions using ‘antique’ weapons (Cavalry, bolt-action rifles, long bayonets)?
# story read in 1960/70s ?anthology. Man wakes up in future, all the people living on earth are stupid, clever people live underground at S pole
# Geometric reasoning problem with a circle
# What are the checks and balances in the US against a President's takeover of governmental personnel?
# Why is common ground needed for a LN298N project
# All women infertile except one child
# more hot questions
# Stack Overflow
# Questions
# Help
# Chat
# Products
# Teams
# Advertising
# Talent
# Company
# About
# Press
# Work Here
# Legal
# Privacy Policy
# Terms of Service
# Contact Us
# Cookie Settings
# Cookie Policy
# Stack Exchange Network
# Technology
# Culture & recreation
# Life & arts
# Science
# Professional
# Business
# API
# Data
# Blog
# Facebook
# Twitter
# LinkedIn
# Instagram
# Site design / logo © 2025 Stack Exchange Inc;
# user contributions licensed under
# CC BY-SA
# .
# rev 2025.2.6.22204

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def summarize(url):
    website = Website(url)
    response = ollama.chat(
        model = model_name,
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt_for(website)}
        ],
        stream=False
    )
    return response.message.content

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://stackoverflow.com/")
# Out:
# <think>
# Okay, so I'm trying to figure out how to make the water in my sink boil faster. The problem is that even when I turn on the heat, it just boils a little bit and then stops. I've tried stirring the water, but nothing seems to help. Hmm, maybe the solution isn't as straightforward as throwing in more effort.
#
# First, I remember hearing about something called the "bubbling flow" hypothesis. From what I can recall, when you stir a liquid on its surface, it makes some bubbles form, which actually speeds up boiling because they're moving around and creating areas where evaporation is easier. So maybe if I add more stirrers or use a whisk, that could help.
#
# I also think about the "mixing" theory, but I'm not sure how to apply that here. Maybe if I let the water mix better before adding heat, it would start boiling faster? But how exactly does mixing help with boiling speed?
#
# Another thought: sometimes people talk about using a "bubble tank." If I fill a small container in the sink with extra water and stir it, maybe that will create more bubbles around the main water. That could enhance the bubbling flow effect.
#
# I should try these methods one by one to see what works best. Maybe start by adding a few more stirs or whiskes and see how the water reacts. If I notice bubbles forming quickly in some areas but not others, maybe I need to focus on specific spots where evaporation is happening most efficiently.
#
# Also, perhaps using an immersion heater would help. If I can get the sink into the heat cycle itself, that might provide a stronger source of heat and make boiling more consistent. But I'm not sure how to adjust it just right without overcooking things.
#
# I wonder if temperature control plays a role here. If my stove isn't heating up evenly, maybe adjusting the settings could help distribute the heat better around the sink area. Or perhaps using an induction cooktop instead of a regular stove would be more efficient in this case.
#
# Wait, I think I've heard about "stirring with effort" and how it can enhance boiling. Maybe I should try doing multiple stirs at different times of the day to see if there's a pattern or if one time is inherently better for boiling.
#
# Another idea: sometimes people use micro-bubbles in water. If adding these somehow helps, but I don't think that's necessary or practical here. It might just be another way of thinking about the bubbling flow effect.
#
# I should also consider the material of my sink. Maybe using something more porous surface with lots of tiny holes could help by increasing contact area and allowing for better evaporation of water.
#
# If none of these methods work, perhaps I need to look into professional assistance or experienced techniques. There might be specific tools or equipment recommended for this kind of task. I think I've heard terms like "bubble therapy" before, but I'm not sure about the specifics or where to find resources on that.
#
# In summary, my initial thoughts are focusing on enhancing bubble formation through stirring and using smaller containers. Adjusting heat distribution or switching to an immersion heater might also be worth trying in a step-by-step manner.
# </think>
#
# To address the issue of boiling water more effectively in your sink, here's a structured approach based on your thought process:
#
# 1. **Bubble Formation Enhancement:**
#    - **Stirring and Whisking:** Add a few more stirs or use a whisk to increase bubble formation. Stirring can create moving bubbles which facilitate easier evaporation.
#    - **Bubbling Flow Hypothesis:** Stirred water can promote a bubbling flow, speeding up boiling.
#
# 2. **Mixing Theory Consideration:**
#    - Although less directly applicable, thorough mixing might slightly improve evaporation efficiency by providing better distribution of heat and moisture.
#
# 3. **Use of a Bubble Tank:**
#    - Fill a small container with extra water in the sink to stir it thoroughly. This can create more bubbles around your main water surface.
#
# 4. **Heat Distribution:**
#    - Adjust temperature settings on your stove or consider an induction cooktop for even heating, which might help maintain consistent heat distribution.
#
# 5. **Adjusting Material Properties:**
#    - Use a porous sink with lots of tiny holes to enhance contact area and facilitate bubble formation.
#
# 6. **Professional Assistance:**
#    - If the above methods don't work, seek professional assistance or consider specialized techniques, possibly exploring resources on "bubble therapy" for more specific solutions.
#
# By systematically trying these methods in sequence, you can identify which adjustments yield the best results for boiling water faster.
